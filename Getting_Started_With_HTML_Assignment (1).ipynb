# %% [markdown]
# 1.Write a simple program in HTML that displays the heading "HTML defines the content and structure of
# your website” on the web browser?
#
# <!DOCTYPE html>
# <html>
# <head>
# 	<meta charset="utf-8">
# 	<meta name="viewport" content="width=device-width, initial-scale=1">
# 	<title>heading</title>
# </head>
# <body>
# <h1>"HTML defines the content and structure of your website” </h1>
# </body>
# </html>

# %%
<!DOCTYPE html>
<html>
<head>
	<meta charset="utf-8">
	<meta name="viewport" content="width=device-width, initial-scale=1">
	<title>heading</title>
</head>
<body>
<h1>"HTML defines the content and structure of your website” </h1>
</body>
</html>

# %% [markdown]
# 2. Explain the purpose of comments in HTML and provide an example of how to use comments in an HTML document?
#    - comment in html or in any programming language is used for to give any message or we use comment to remember anything regarding our code, this lines are not executable or not read by the compiler and do not appear on the webpage, so now see how can we use comment in our html program.
#
#    <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="utf-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#     <title>heading</title>
# </head>
# <body>
# <h1>"HTML defines the content and structure of
# your website”</h1>
# <!-- this is a comment-->
# </body>
# </html>

# %%
<!DOCTYPE html>
<html>
<head>
    <meta charset="utf-8">
    <meta name="viewport" content="width=device-width, initial-scale=1">
    <title>heading</title>
</head>
<body>
<h1>"HTML defines the content and structure of
your website”</h1>
<!-- this is a comment-->
</body>
</html>
# Out:
#   File "<ipython-input-8-ff908cd85a05>", line 9
#     <h1>"HTML defines the content and structure of
#         ^
# SyntaxError: unterminated string literal (detected at line 9)

# %% [markdown]
# 3. Write an HTML program that includes a heading, a paragraph of text, a horizontal line, and a line break.
# Arrange these elements to create a simple web page layout?
#
# <!DOCTYPE html>
# <html>
# <head>
#   <title>Simple Web Page</title>
# </head>
# <body>
#   <h1>Welcome to My Web Page</h1>
#
#   <p>hi how are you</p>
#
#   <hr>
#
#   <p>This is the first line.
#
#   <br>
#
#   This is the second line after a line break.</p>
#
# </body>
# </html>

# %%
<!DOCTYPE html>
<html>
<head>
  <title>Simple Web Page</title>
</head>
<body>
  <h1>Welcome to My Web Page</h1>

  <p>hi how are you</p>

  <hr>

  <p>This is the first line.

  <br>

  This is the second line after a line break.</p>

</body>
</html>
# Out:
#   File "<ipython-input-10-409321f14f62>", line 1
#     <!DOCTYPE html>
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# 4. Write a short note on Tag and element with an example?
#    - a tag in HTML is a keyword enclosed in angular bracket
#    -tags are always comes in pair opening tag and closing tag
#    example:-

# %%
"""
   paragraph tag - <p> </p>
   heading tag -<h1> </h1>
   horizontal line tag <hr>
   line break tag <br>..etc
"""

# %% [markdown]
#  5.What is the DOCTYPE Declaration in HTML?
#    - The <!DOCTYPE> declaration is used at the very beginning of an HTML document to tell the web browser which version of HTML the page is written in.
# For HTML5, the declaration is:
# <!DOCTYPE html>

# %%
# Out:
#   File "<ipython-input-7-455286c21ce6>", line 9
#     <html>
#     ^
# SyntaxError: invalid syntax
